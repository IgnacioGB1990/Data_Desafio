# %%
import pandas as pd

#Rough
df = pd.read_csv("./data/provincias.csv")

df.head(5)
# Out:
#    OBJECTID  Codigo        Texto  Cod_CCAA provNombre  provCodigo  \
# 0         1       1  Araba/Álava        16      Araba           1
# 1         2       2     Albacete         8   Albacete           2
# 2         3       3     Alicante        10    Alacant           3
# 3         4       4      Almería         1    Almeria           4
# 4         5       5        Ávila         7      Avila           5
#
#    GastoTotalSuministroAgua2019  GastoTotalSuministroAgua2018  \
# 0                  1.859490e+07                  2.016887e+07
# 1                  2.008376e+07                  2.358253e+07
# 2                  1.655175e+08                  1.611876e+08
# 3                  5.258781e+07                  5.696283e+07
# 4                  6.777609e+06                  7.930044e+06
#
#    GastoTotalSuministroAgua2017  GastoTotalSuministroAgua2016  ...  \
# 0                  1.993225e+07                  1.787263e+07  ...
# ...
