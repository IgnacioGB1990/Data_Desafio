# %%
import pandas as pd

# %%
# Fullstack hará un endpoint en la base de datos al final del cuestionarios. Obtendrán un objeto JSON determinado que convertiran a string mediante un JSON.stringify() que será lo que recibiremos.
# Este objeto viene en forma de diccionario de Python con clave:valor = pregunta:respuesta. Pero como objeto JSON.stringify es un STRING, no un diccionario.
# Deberemos de parsearlo con la función json.loads('string_de_fullstack'). Obtendremos un diccionario de la forma pregunta:respuesta.
# Deberemos coger los valores y formar una lista con ellos. Nos servirá tanto para el modelo como para los cálculos, cuyo código haremos a continuación.

# Importamos json:
import json

# Este será el objeto json.stringify():
string_fullstack = 'a'

# Convertimos a diccionario y hacemos una lista con los valores:

diccionario = json.loads('string_fullstack')
respuesta_usuario = list(diccionario.values())

# %%
# La lista será de 15 elementos, uno por respuesta (aquí un ejemplo):

# respuesta_usuario = ['Entre 18 y 35 años', 4, 'Madrid', 'Ahorrar dinero', 'Entre 5 y 10 minutos', 'Menos de 3 veces', 
#                      'Friego a mano', 'Siempre', 'No', 'Siempre', '1 vez al día', 'Más de 200 Km', 'No tengo mascota', 0, 'Entre 10€ y 40€']

# Nos interesán para el cálculo los elementos del 5 al 14.

# %%
df = pd.read_csv('../data/typeform_igb.csv')
df.head()
# Out:
#                                   # ¿En qué rango de edad te encuentras?  \
# 0  cb2hsyhk4q48anbuacl1cb2hspesvqca                   Entre 36 y 65 años
# 1  1lvp0ymwpl878xcfgo1lvp0yhw1vy0ld                   Entre 36 y 65 años
# 2  t5e8kn9ug41t5zdgpgnt5e8kn9dx7xba                   Entre 36 y 65 años
# 3  lhrk180jtc1swhx2plhrk18wntdhnix6                   Entre 18 y 35 años
# 4  6mv5t8yarw67kj343annxsb6mv5t8yhx                   Entre 36 y 65 años
#
#    ¿Cuántas personas sois en vuestro hogar?  \
# 0                                       4.0
# 1                                       3.0
# 2                                       2.0
# 3                                       2.0
# 4                                       2.0
#
#   ¿En qué provincia vives? Vamos a conocernos un poco mejor 😄  \
# 0                                             Madrid
# 1                                            Segovia
# 2                                            Segovia
# 3                                            Segovia
# 4                                             Madrid
#
#   ¿De cuál de estos temas te interesaría saber más? ¿Cuánto duran tus duchas?  \
# 0                              Ayudar al ecosistema      Entre 5 y 10 minutos
# 1                              Ayudar al ecosistema        Menos de 5 minutos
# 2                                    Ahorrar dinero        Menos de 5 minutos
# 3                                      Ahorrar agua      Entre 5 y 10 minutos
# 4                                      Ahorrar agua      Entre 5 y 10 minutos
#
#   ¿Cuántas veces pones la lavadora a la semana?  \
# 0                             Entre 3 y 5 veces
# 1                              Menos de 3 veces
# 2                              Menos de 3 veces
# 3                              Menos de 3 veces
# 4                              Menos de 3 veces
#
#   ¿Cuántas veces pones el lavavajillas?  \
# 0               Entre 3 y 5 a la semana
# 1               Entre 3 y 5 a la semana
# 2                         Friego a mano
# 3                         Friego a mano
# 4                         Friego a mano
#
#   ¿Sueles poner el modo *ECO *en tus electrodomésticos?  \
# 0                                            A veces
# 1                                            Siempre
# 2                      No sabía que existía ese modo
# 3                                            Siempre
# 4                                            A veces
#
#   ¿Reciclas agua para usarlo en otras tareas?  \
# 0                                          No
# 1                                          No
# 2                                          No
# 3                                          No
# 4                                          Si
#
#   ¿*Reciclas *vidrio, cartón y plástico? ¿Cada cuánto consumes *carne*?  \
# 0                                Siempre                   1 vez al día
# 1                                A veces              1 vez cada 3 días
# 2                                A veces              1 vez a la semana
# 3                                A veces                   1 vez al día
# 4                                Siempre              1 vez cada 3 días
#
#   ¿Cuántos km haces a la semana en coche?  \
# 0                           Más de 200 km
# 1                         Menos de 100 km
# 2                            100 - 200 km
# 3                         Menos de 100 km
# 4                            No uso coche
#
#   ¿Cuánto gastas al mes en comida para gato/perro?  \
# 0                                 No tengo mascota
# 1                                 No tengo mascota
# 2                                 No tengo mascota
# 3                                 No tengo mascota
# 4                                 No tengo mascota
#
#   ¿Cuántos metros cuadrados tiene tu jardín?  \
# 0                                          0
# 1                                        300
# 2                                          0
# 3                                          0
# 4                                          2
#
#   ¿Sabes cuánto dinero gastas en tu consumo de agua al mes?  \
# 0                                           Ni idea!
# 1                                           Ni idea!
# 2                                           Ni idea!
# 3                                           Ni idea!
# 4                                   Entre 10€ y 40 €
#
#       Start Date (UTC)    Submit Date (UTC)  Network ID Tags;
# 0  2023-05-18 05:55:47  2023-05-18 05:58:06  31494a64d0     ;
# 1  2023-05-18 05:36:34  2023-05-18 05:38:17  26873d694b     ;
# 2  2023-05-18 05:31:31  2023-05-18 05:33:35  6050316def     ;
# 3  2023-05-18 05:22:13  2023-05-18 05:23:42  903866689d     ;
# 4  2023-05-18 05:05:50  2023-05-18 05:08:08  1acecc257c     ;

# %%
df.dropna(inplace=True)

# %%
df['¿*Reciclas *vidrio, cartón y plástico?'].unique()
# Out:
# array(['Siempre', 'A veces', 'Nunca!'], dtype=object)

# %%
# Nos ayudamos de expresiones regulares para la decimocuarta respuesta:
import re

# Definimos una función que calcule la huella hídrica total anual por cada respuesta de usuario:

def huella_hídrica_total_anual(row):

    quinto_elemento = row['¿Cuánto duran tus duchas?']
    sexto_elemento = row['¿Cuántas veces pones la lavadora a la semana?']
    septimo_elemento = row['¿Cuántas veces pones el lavavajillas?']
    octavo_elemento = row['¿Sueles poner el modo *ECO *en tus electrodomésticos?']
    noveno_elemento = row['¿Reciclas agua para usarlo en otras tareas?']
    decimo_elemento = row['¿*Reciclas *vidrio, cartón y plástico?']
    undecimo_elemento = row['¿Cada cuánto consumes *carne*?']
    duodecimo_elemento = row['¿Cuántos km haces a la semana en coche?']
    decimotercero_elemento = row['¿Cuánto gastas al mes en comida para gato/perro?']
    decimocuarto_elemento = row['¿Cuántos metros cuadrados tiene tu jardín?']


    if quinto_elemento == 'Menos de 5 minutos':
        huella_hidrica_ducha = 5 * (4 * 2.5 / 60) * 0.01 * 52 * 1000

    elif quinto_elemento == 'Entre 5 y 10 minutos':
        huella_hidrica_ducha = 5 * (7 * 2.5 / 60) * 0.01 * 52 * 1000

    elif quinto_elemento == 'Entre 11 y 15 minutos':
        huella_hidrica_ducha = 5 * (12 * 2.5 / 60) * 0.01 * 52 * 1000

    elif quinto_elemento == 'Más de 15 minutos':
        huella_hidrica_ducha = 5 * (20 * 2.5 / 60) * 0.01 * 52 * 1000


    if sexto_elemento == 'Menos de 3 veces':
        huella_hidrica_lavadora = 1 * 15 * 0.01 * 52 * 1000
        
    elif sexto_elemento == 'Entre 3 y 5 veces':
        huella_hidrica_lavadora = 4 * 15 * 0.01 * 52 * 1000

    elif sexto_elemento == 'Más de 5':
        huella_hidrica_lavadora = 6 * 15 * 0.01 * 52 * 1000


    if septimo_elemento == '1 vez al día':
        huella_hidrica_lavar_platos = 1 * 6.5 * 0.01 * 52 * 1000

    elif septimo_elemento == 'Entre 3 y 5 a la semana':
        huella_hidrica_lavar_platos = 5 * 6.5 * 0.01 * 52 * 1000

    elif septimo_elemento == 'Friego a mano':
        huella_hidrica_lavar_platos = 10 * 27 * 0.01 * 52 * 1000


    if octavo_elemento == 'Siempre':
        huella_hidrica_para_modo_eco = - ((7800 + 23659.3) * 36) / 100

    elif octavo_elemento == 'A veces':
        huella_hidrica_para_modo_eco = - ((7800 + 23659.3) * 18) / 100

    elif octavo_elemento == 'No sabía que existía ese modo':
        huella_hidrica_para_modo_eco = 0


    if noveno_elemento == 'Si':
        huella_hidrica_ahorro_agua = - 730

    elif noveno_elemento == 'No':
        huella_hidrica_ahorro_agua = 0

    elif noveno_elemento == 'Buena idea! Voy a probarlo!':
        huella_hidrica_ahorro_agua = 0


    if decimo_elemento == 'A veces':
        huella_hidrica_reciclaje = - 730

    elif decimo_elemento == 'Siempre':
        huella_hidrica_reciclaje = - 1460

    elif decimo_elemento == 'Nunca!':
        huella_hidrica_reciclaje = 0


    if undecimo_elemento == '1 vez al día':
        huella_hidrica_carne = 768 * 0.01 * 1000 * 365

    elif undecimo_elemento == '1 vez cada 3 días':
        huella_hidrica_carne = 596 * 0.01 * 1000 * 365

    elif undecimo_elemento == '1 vez a la semana':
        huella_hidrica_carne = 563 * 0.01 * 1000 * 365

    elif undecimo_elemento == 'Nunca!':
        huella_hidrica_carne = 406 * 0.01 * 1000 * 365


    if duodecimo_elemento == 'Menos de 100 km':
        huella_hidrica_gasolina = (6 * 52) * 97

    elif duodecimo_elemento == '100 - 200 km':
        huella_hidrica_gasolina = (15 * 52) * 97

    elif duodecimo_elemento == 'Más de 200 km':
        huella_hidrica_gasolina = (25 * 52) * 97

    elif duodecimo_elemento == 'No uso coche':
        huella_hidrica_gasolina = 0


    if decimotercero_elemento == 'No tengo mascota':
        huella_hidrica_mascota = 358.75 * 1000

    elif decimotercero_elemento == 'Menos de 50 €':
        huella_hidrica_mascota = 40 * 358750 / 75

    elif decimotercero_elemento == 'Entre 50 y 100 €':
        huella_hidrica_mascota = 75 * 358750 / 75

    elif decimotercero_elemento == 'Más de 100 €':
        huella_hidrica_mascota = 120 * 358750 / 75


    if decimocuarto_elemento.isdigit():
        huella_hidrica_jardin = 6 * int(decimocuarto_elemento)
    else:
        numero_encontrado = re.search(r'\d+', decimocuarto_elemento)
        if numero_encontrado:
            huella_hidrica_jardin = 6 * int(numero_encontrado.group())
        else:
            huella_hidrica_jardin = 0

    huella_hidrica_total_anual  = huella_hidrica_ducha + huella_hidrica_lavadora + huella_hidrica_lavar_platos + huella_hidrica_para_modo_eco + huella_hidrica_ahorro_agua + huella_hidrica_reciclaje + huella_hidrica_carne + huella_hidrica_gasolina + huella_hidrica_mascota + huella_hidrica_jardin

    return huella_hidrica_total_anual

# %%
# Definimos una función que calcule la huella hídrica total diaria por cada respuesta de usuario:

def huella_hídrica_total_diaria(huella_hidrica_total_anual):

    huella_hidrica_total_diaria = huella_hidrica_total_anual / 365

    return huella_hidrica_total_diaria

# %%
Huella_Hídrica_Anual = df.apply(huella_hídrica_total_anual, axis=1)

df['Huella Hidrica Anual'] = Huella_Hídrica_Anual

# %%
df.head()
# Out:
#                                   # ¿En qué rango de edad te encuentras?  \
# 0  cb2hsyhk4q48anbuacl1cb2hspesvqca                   Entre 36 y 65 años
# 1  1lvp0ymwpl878xcfgo1lvp0yhw1vy0ld                   Entre 36 y 65 años
# 2  t5e8kn9ug41t5zdgpgnt5e8kn9dx7xba                   Entre 36 y 65 años
# 3  lhrk180jtc1swhx2plhrk18wntdhnix6                   Entre 18 y 35 años
# 4  6mv5t8yarw67kj343annxsb6mv5t8yhx                   Entre 36 y 65 años
#
#    ¿Cuántas personas sois en vuestro hogar?  \
# 0                                       4.0
# 1                                       3.0
# 2                                       2.0
# 3                                       2.0
# 4                                       2.0
#
#   ¿En qué provincia vives? Vamos a conocernos un poco mejor 😄  \
# 0                                             Madrid
# 1                                            Segovia
# 2                                            Segovia
# 3                                            Segovia
# 4                                             Madrid
#
#   ¿De cuál de estos temas te interesaría saber más? ¿Cuánto duran tus duchas?  \
# 0                              Ayudar al ecosistema      Entre 5 y 10 minutos
# 1                              Ayudar al ecosistema        Menos de 5 minutos
# 2                                    Ahorrar dinero        Menos de 5 minutos
# 3                                      Ahorrar agua      Entre 5 y 10 minutos
# 4                                      Ahorrar agua      Entre 5 y 10 minutos
#
#   ¿Cuántas veces pones la lavadora a la semana?  \
# 0                             Entre 3 y 5 veces
# 1                              Menos de 3 veces
# 2                              Menos de 3 veces
# 3                              Menos de 3 veces
# 4                              Menos de 3 veces
#
#   ¿Cuántas veces pones el lavavajillas?  \
# 0               Entre 3 y 5 a la semana
# 1               Entre 3 y 5 a la semana
# 2                         Friego a mano
# 3                         Friego a mano
# 4                         Friego a mano
#
#   ¿Sueles poner el modo *ECO *en tus electrodomésticos?  \
# 0                                            A veces
# 1                                            Siempre
# 2                      No sabía que existía ese modo
# 3                                            Siempre
# 4                                            A veces
#
#   ¿Reciclas agua para usarlo en otras tareas?  ...  \
# 0                                          No  ...
# 1                                          No  ...
# 2                                          No  ...
# 3                                          No  ...
# 4                                          Si  ...
#
#   ¿Cada cuánto consumes *carne*? ¿Cuántos km haces a la semana en coche?  \
# 0                   1 vez al día                           Más de 200 km
# 1              1 vez cada 3 días                         Menos de 100 km
# 2              1 vez a la semana                            100 - 200 km
# 3                   1 vez al día                         Menos de 100 km
# 4              1 vez cada 3 días                            No uso coche
#
#   ¿Cuánto gastas al mes en comida para gato/perro?  \
# 0                                 No tengo mascota
# 1                                 No tengo mascota
# 2                                 No tengo mascota
# 3                                 No tengo mascota
# 4                                 No tengo mascota
#
#   ¿Cuántos metros cuadrados tiene tu jardín?  \
# 0                                          0
# 1                                        300
# 2                                          0
# 3                                          0
# 4                                          2
#
#   ¿Sabes cuánto dinero gastas en tu consumo de agua al mes?  \
# 0                                           Ni idea!
# 1                                           Ni idea!
# 2                                           Ni idea!
# 3                                           Ni idea!
# 4                                   Entre 10€ y 40 €
#
#       Start Date (UTC)    Submit Date (UTC)  Network ID Tags;  \
# 0  2023-05-18 05:55:47  2023-05-18 05:58:06  31494a64d0     ;
# 1  2023-05-18 05:36:34  2023-05-18 05:38:17  26873d694b     ;
# 2  2023-05-18 05:31:31  2023-05-18 05:33:35  6050316def     ;
# 3  2023-05-18 05:22:13  2023-05-18 05:23:42  903866689d     ;
# 4  2023-05-18 05:05:50  2023-05-18 05:08:08  1acecc257c     ;
#
#   Huella Hidrica Anual
# 0         3.329786e+06
# 1         2.579292e+06
# 2         2.637263e+06
# 3         3.329117e+06
# 4         2.675268e+06
#
# [5 rows x 21 columns]

# %%
lista_huella_anual = df['Huella Hidrica Anual'].values.tolist()

# %%
df
# Out:
#                                      # ¿En qué rango de edad te encuentras?  \
# 0     cb2hsyhk4q48anbuacl1cb2hspesvqca                   Entre 36 y 65 años
# 1     1lvp0ymwpl878xcfgo1lvp0yhw1vy0ld                   Entre 36 y 65 años
# 2     t5e8kn9ug41t5zdgpgnt5e8kn9dx7xba                   Entre 36 y 65 años
# 3     lhrk180jtc1swhx2plhrk18wntdhnix6                   Entre 18 y 35 años
# 4     6mv5t8yarw67kj343annxsb6mv5t8yhx                   Entre 36 y 65 años
# ...                                ...                                  ...
# 1176  7x1qng5kvkuh27b7x1q2151il5mmbwuq                   Entre 36 y 65 años
# 1177  kgfkzrwdifwp7fn4vkgeh1tfdwhq2kws                   Entre 36 y 65 años
# 1178  tvr4w2o8fmyit3j8sztvr4w23gxxfx5x                   Entre 18 y 35 años
# 1179  fgwwabxkti6hvs1bjn7fgwwabxph7zmr                   Entre 18 y 35 años
# 1180  hf2ao9dlukff34la4whf2i5ff9a7ggyp                   Entre 36 y 65 años
#
#       ¿Cuántas personas sois en vuestro hogar?  \
# 0                                          4.0
# 1                                          3.0
# 2                                          2.0
# 3                                          2.0
# 4                                          2.0
# ...                                        ...
# 1176                                       4.0
# 1177                                       5.0
# 1178                                       3.0
# 1179                                       4.0
# 1180                                       5.0
#
#      ¿En qué provincia vives? Vamos a conocernos un poco mejor 😄  \
# 0                                                Madrid
# 1                                               Segovia
# 2                                               Segovia
# 3                                               Segovia
# 4                                                Madrid
# ...                                                 ...
# 1176                                             Madrid
# 1177                                             Madrid
# 1178                                             Madrid
# 1179                                             Madrid
# 1180                                             Madrid
#
#      ¿De cuál de estos temas te interesaría saber más?  \
# 0                                 Ayudar al ecosistema
# 1                                 Ayudar al ecosistema
# 2                                       Ahorrar dinero
# 3                                         Ahorrar agua
# 4                                         Ahorrar agua
# ...                                                ...
# 1176                                      Ahorrar agua
# 1177                                    Ahorrar dinero
# 1178                         Conocer mi huella hídrica
# 1179                                    Ahorrar dinero
# 1180                                    Ahorrar dinero
#
#      ¿Cuánto duran tus duchas? ¿Cuántas veces pones la lavadora a la semana?  \
# 0         Entre 5 y 10 minutos                             Entre 3 y 5 veces
# 1           Menos de 5 minutos                              Menos de 3 veces
# 2           Menos de 5 minutos                              Menos de 3 veces
# 3         Entre 5 y 10 minutos                              Menos de 3 veces
# 4         Entre 5 y 10 minutos                              Menos de 3 veces
# ...                        ...                                           ...
# 1176      Entre 5 y 10 minutos                             Entre 3 y 5 veces
# 1177        Menos de 5 minutos                                      Más de 5
# 1178     Entre 11 y 15 minutos                              Menos de 3 veces
# 1179      Entre 5 y 10 minutos                             Entre 3 y 5 veces
# 1180     Entre 11 y 15 minutos                             Entre 3 y 5 veces
#
#      ¿Cuántas veces pones el lavavajillas?  \
# 0                  Entre 3 y 5 a la semana
# 1                  Entre 3 y 5 a la semana
# 2                            Friego a mano
# 3                            Friego a mano
# 4                            Friego a mano
# ...                                    ...
# 1176               Entre 3 y 5 a la semana
# 1177               Entre 3 y 5 a la semana
# 1178               Entre 3 y 5 a la semana
# 1179                         Friego a mano
# 1180                         Friego a mano
#
#      ¿Sueles poner el modo *ECO *en tus electrodomésticos?  \
# 0                                               A veces
# 1                                               Siempre
# 2                         No sabía que existía ese modo
# 3                                               Siempre
# 4                                               A veces
# ...                                                 ...
# 1176                                            A veces
# 1177                      No sabía que existía ese modo
# 1178                                            A veces
# 1179                                            A veces
# 1180                                            A veces
#
#      ¿Reciclas agua para usarlo en otras tareas?  ...  \
# 0                                             No  ...
# 1                                             No  ...
# 2                                             No  ...
# 3                                             No  ...
# 4                                             Si  ...
# ...                                          ...  ...
# 1176                                          No  ...
# 1177                                          No  ...
# 1178                 Buena idea! Voy a probarlo!  ...
# 1179                                          No  ...
# 1180                                          No  ...
#
#      ¿Cada cuánto consumes *carne*? ¿Cuántos km haces a la semana en coche?  \
# 0                      1 vez al día                           Más de 200 km
# 1                 1 vez cada 3 días                         Menos de 100 km
# 2                 1 vez a la semana                            100 - 200 km
# 3                      1 vez al día                         Menos de 100 km
# 4                 1 vez cada 3 días                            No uso coche
# ...                             ...                                     ...
# 1176                   1 vez al día                         Menos de 100 km
# 1177              1 vez a la semana                            100 - 200 km
# 1178                   1 vez al día                           Más de 200 km
# 1179                   1 vez al día                           Más de 200 km
# 1180              1 vez cada 3 días                            No uso coche
#
#      ¿Cuánto gastas al mes en comida para gato/perro?  \
# 0                                    No tengo mascota
# 1                                    No tengo mascota
# 2                                    No tengo mascota
# 3                                    No tengo mascota
# 4                                    No tengo mascota
# ...                                               ...
# 1176                                 No tengo mascota
# 1177                                 No tengo mascota
# 1178                                 Entre 50 y 100 €
# 1179                                 No tengo mascota
# 1180                                 No tengo mascota
#
#      ¿Cuántos metros cuadrados tiene tu jardín?  \
# 0                                             0
# 1                                           300
# 2                                             0
# 3                                             0
# 4                                             2
# ...                                         ...
# 1176                                          0
# 1177                                          0
# 1178                                          0
# 1179                                          0
# 1180                                          0
#
#      ¿Sabes cuánto dinero gastas en tu consumo de agua al mes?  \
# 0                                              Ni idea!
# 1                                              Ni idea!
# 2                                              Ni idea!
# 3                                              Ni idea!
# 4                                      Entre 10€ y 40 €
# ...                                                 ...
# 1176                                           Ni idea!
# 1177                                   Entre 10€ y 40 €
# 1178                                   Entre 10€ y 40 €
# 1179                                   Entre 10€ y 40 €
# 1180                                        Más de 40 €
#
#          Start Date (UTC)    Submit Date (UTC)  Network ID Tags;  \
# 0     2023-05-18 05:55:47  2023-05-18 05:58:06  31494a64d0     ;
# 1     2023-05-18 05:36:34  2023-05-18 05:38:17  26873d694b     ;
# 2     2023-05-18 05:31:31  2023-05-18 05:33:35  6050316def     ;
# 3     2023-05-18 05:22:13  2023-05-18 05:23:42  903866689d     ;
# 4     2023-05-18 05:05:50  2023-05-18 05:08:08  1acecc257c     ;
# ...                   ...                  ...         ...   ...
# 1176  2023-05-16 12:07:19  2023-05-16 12:09:09  ba62a97a55     ;
# 1177  2023-05-16 12:06:05  2023-05-16 12:07:51  6c0089c4f9     ;
# 1178  2023-05-16 11:57:31  2023-05-16 12:02:52  adc183527a     ;
# 1179  2023-05-16 11:54:03  2023-05-16 11:59:24  a2c1b4b956     ;
# 1180  2023-05-16 11:52:27  2023-05-16 11:54:36  adc183527a     ;
#
#      Huella Hidrica Anual
# 0            3.329786e+06
# 1            2.579292e+06
# 2            2.637263e+06
# 3            3.329117e+06
# 4            2.675268e+06
# ...                   ...
# 1176         3.233950e+06
# 1177         2.553493e+06
# 1178         3.307657e+06
# 1179         3.453286e+06
# 1180         2.700657e+06
#
# [1116 rows x 21 columns]

# %%
media_total_anual = sum(lista_huella_anual) / 1116
media_total_anual
# Out:
# 2761438.619201918

# %%
media_total_diaria = (media_total_anual / 365)
media_total_diaria
# Out:
# 7565.585258087447
