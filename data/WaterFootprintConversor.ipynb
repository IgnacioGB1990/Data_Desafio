# %%
import pandas as pd
pd.set_option('display.max_colwidth', 200)

# %% [markdown]
# # Conversiones de huella hídrica por litros.
#
# ### Cálculos basados en estimaciones promedio de USA.

# %%
conversiones = {'Huellas' : ['Huella Hídrica Agua',
                             'Cantidad Agua/Ducha',
                             'Huella Hidrica (Ducha)',
                             'Cantidad Agua/Lavadora',
                             'Huella hidrica lavadora',
                             'Cantidad Agua/Lavavajillas',
                             'Huella hidrica lavavajillas',
                             'Cantidad Agua/Platos a Mano',
                             'Huella hidrica Platos a Mano',
                             'Modo ECO',
                             'Reciclajes (Buscar)',
                             'Consumo de Carne',
                             'Huella hídrica Gasolina',
                             'Cantidad Agua/Lavado del Coche',
                             'Huella hidrica Lavado del Coche',
                             'Comida Mascota',
                             'Cantidad Agua/Jardín',
                             'Huella hidrica Riego',
                             'Huella hidrica total'],
                'Cálculo' : ['0.01',
                             '(Minutos de ducha * 2.5) / 60',
                             'Número duchas/semana * Cantidad Agua/Ducha * Huella Hídrica Agua * 52 (Semanas/año) * 1000 (Litros en 1 m3)',
                             '15',
                             'Número lavadoras/semana * Cantidad Agua/Lavadora * Huella Hídrica Agua * 52 (Semanas/año) * 1000 (Litros en 1 m3)',
                             '6.5',
                             'Número lavavajillas/semana * Cantidad Agua/Lavavajillas * Huella Hídrica Agua * 52 (Semanas/año) * 1000 (Litros en 1 m3)',
                             '27',
                             'Número platos a mano/semana * Cantidad Agua/Platos a Mano * Huella Hídrica Agua * 52 (Semanas/año) * 1000 (Litros en 1 m3)',
                             '36%',
                             'NS/NC',
                             'Media (Buscar)',
                             '97',
                             '120',
                             'Número lavados de coche/mes * Cantidad Agua/Lavado del Coche * Huella Hídrica Agua * 12 (Meses/año) * 1000 (Litros en 1 m3)',
                             'NS/NC',
                             '6.7',
                             'Número riegos/semana * Cantidad Agua/Jardín * Huella Hídrica Agua * 52 (Semanas/año) * 1000 (Litros en 1 m3)',
                             'Sumatorio total'],
                'Unidades' : ['m3/galón (Factor promedio para calcular según métricas de USA).',
                              'Galones',
                              'Litros/Año',
                              'Galones',
                              'Litros/Año',
                              'Galones',
                              'Litros/Año',
                              'Galones',
                              'Litros/Año',
                              'De media en todos los electrodomesticos',
                              'NS/NC',
                              'Media (Buscar)',
                              'Litros Agua por 1L Gasoilina',
                              'Galones',
                              'Litros/Agua',
                              'NS/NC',
                              'Galones (Esto es para el riego, habría que buscar más info)',
                              'Litros/Año',
                              'Litros/Año']}

# %%
df = pd.DataFrame(conversiones)
df
# Out:
#                             Huellas  \
# 0               Huella Hídrica Agua
# 1               Cantidad Agua/Ducha
# 2            Huella Hidrica (Ducha)
# 3            Cantidad Agua/Lavadora
# 4           Huella hidrica lavadora
# 5        Cantidad Agua/Lavavajillas
# 6       Huella hidrica lavavajillas
# 7       Cantidad Agua/Platos a Mano
# 8      Huella hidrica Platos a Mano
# 9                          Modo ECO
# 10              Reciclajes (Buscar)
# 11                 Consumo de Carne
# 12          Huella hídrica Gasolina
# 13   Cantidad Agua/Lavado del Coche
# 14  Huella hidrica Lavado del Coche
# 15                   Comida Mascota
# 16             Cantidad Agua/Jardín
# 17             Huella hidrica Riego
# 18             Huella hidrica total
#
#                                                                                                                         Cálculo  \
# 0                                                                                                                          0.01
# 1                                                                                                 (Minutos de ducha * 2.5) / 60
# 2                   Número duchas/semana * Cantidad Agua/Ducha * Huella Hídrica Agua * 52 (Semanas/año) * 1000 (Litros en 1 m3)
# 3                                                                                                                            15
# 4             Número lavadoras/semana * Cantidad Agua/Lavadora * Huella Hídrica Agua * 52 (Semanas/año) * 1000 (Litros en 1 m3)
# 5                                                                                                                           6.5
# 6      Número lavavajillas/semana * Cantidad Agua/Lavavajillas * Huella Hídrica Agua * 52 (Semanas/año) * 1000 (Litros en 1 m3)
# 7                                                                                                                            27
# 8    Número platos a mano/semana * Cantidad Agua/Platos a Mano * Huella Hídrica Agua * 52 (Semanas/año) * 1000 (Litros en 1 m3)
# 9                                                                                                                           36%
# 10                                                                                                                        NS/NC
# 11                                                                                                               Media (Buscar)
# 12                                                                                                                           97
# 13                                                                                                                          120
# 14  Número lavados de coche/mes * Cantidad Agua/Lavado del Coche * Huella Hídrica Agua * 12 (Meses/año) * 1000 (Litros en 1 m3)
# 15                                                                                                                        NS/NC
# 16                                                                                                                          6.7
# 17                 Número riegos/semana * Cantidad Agua/Jardín * Huella Hídrica Agua * 52 (Semanas/año) * 1000 (Litros en 1 m3)
# 18                                                                                                              Sumatorio total
#
#                                                            Unidades
# 0   m3/galón (Factor promedio para calcular según métricas de USA).
# 1                                                           Galones
# 2                                                        Litros/Año
# 3                                                           Galones
# 4                                                        Litros/Año
# 5                                                           Galones
# 6                                                        Litros/Año
# 7                                                           Galones
# 8                                                        Litros/Año
# 9                           De media en todos los electrodomesticos
# 10                                                            NS/NC
# 11                                                   Media (Buscar)
# 12                                     Litros Agua por 1L Gasoilina
# 13                                                          Galones
# 14                                                      Litros/Agua
# 15                                                            NS/NC
# 16      Galones (Esto es para el riego, habría que buscar más info)
# 17                                                       Litros/Año
# 18                                                       Litros/Año
