# %% [markdown]
# ### Initial Cleaning of Typeform

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns


df = pd.read_csv("../data/typeform_igb.csv")

df.head()
# Out:
#                                   # ¿En qué rango de edad te encuentras?  \
# 0  x0z7dharxz61aofacpx0z7dhgqjszw93                   Entre 36 y 65 años
# 1  8z1t2aewlr3x6188z1t5h64yw16duesv                   Entre 36 y 65 años
# 2  hm432anlwlutkxpsgphmig6nme8hxp5w                   Entre 36 y 65 años
# 3  t7zhnylatjxj7tnqt7zhnpfv0w11wf9m                   Entre 36 y 65 años
# 4  2vb7hl524xvek2vb7fxggcgsb6xa5o3o                   Entre 36 y 65 años
#
#    ¿Cuántas personas sois en vuestro hogar?  \
# 0                                       4.0
# 1                                       2.0
# 2                                       1.0
# 3                                       2.0
# 4                                       2.0
#
#   ¿En qué provincia vives? Vamos a conocernos un poco mejor 😄  \
# 0                                            Segovia
# 1                                             Madrid
# 2                                            Segovia
# 3                                             Madrid
# 4                                             Madrid
#
#   ¿De cuál de estos temas te interesaría saber más? ¿Cuánto duran tus duchas?  \
# 0                                    Ahorrar dinero      Entre 5 y 10 minutos
# 1                                      Ahorrar agua      Entre 5 y 10 minutos
# 2                              Ayudar al ecosistema      Entre 5 y 10 minutos
# 3                              Ayudar al ecosistema      Entre 5 y 10 minutos
# 4                              Ayudar al ecosistema         Más de 15 minutos
#
#   ¿Cuántas veces pones la lavadora a la semana?  \
# 0                             Entre 3 y 5 veces
# 1                              Menos de 3 veces
# 2                              Menos de 3 veces
# 3                             Entre 3 y 5 veces
# 4                             Entre 3 y 5 veces
#
#   ¿Cuántas veces pones el lavavajillas?  \
# 0                         Friego a mano
# 1                          1 vez al día
# 2                         Friego a mano
# 3               Entre 3 y 5 a la semana
# 4                         Friego a mano
#
#   ¿Sueles poner el modo *ECO *en tus electrodomésticos?  \
# 0                                            Siempre
# 1                                            A veces
# 2                                            Siempre
# 3                                            A veces
# 4                                            A veces
#
#   ¿Reciclas agua para usarlo en otras tareas?  \
# 0                 Buena idea! Voy a probarlo!
# 1                                          Si
# 2                                          No
# 3                                          No
# 4                 Buena idea! Voy a probarlo!
#
#   ¿*Reciclas *vidrio, cartón y plástico? ¿Cada cuánto consumes *carne*?  \
# 0                                Siempre                   1 vez al día
# 1                                Siempre              1 vez cada 3 días
# 2                                A veces              1 vez cada 3 días
# 3                                A veces                   1 vez al día
# 4                                A veces              1 vez cada 3 días
#
#   ¿Cuántos km haces a la semana en coche?  \
# 0                         Menos de 100 km
# 1                           Más de 200 km
# 2                         Menos de 100 km
# 3                            No uso coche
# 4                            No uso coche
#
#   ¿Cuánto gastas al mes en comida para gato/perro?  \
# 0                                 No tengo mascota
# 1                                 No tengo mascota
# 2                                 No tengo mascota
# 3                                 No tengo mascota
# 4                                    Menos de 50 €
#
#   ¿Cuántos metros cuadrados tiene tu jardín?  \
# 0                                          0
# 1                                          0
# 2                                          0
# 3                                        NaN
# 4                                          0
#
#   ¿Sabes cuánto dinero gastas en tu consumo de agua al mes?  \
# 0                                   Entre 10€ y 40 €
# 1                                      Menos de 10 €
# 2                                   Entre 10€ y 40 €
# 3                                   Entre 10€ y 40 €
# 4                                      Menos de 10 €
#
#       Start Date (UTC)    Submit Date (UTC)  Network ID  Tags
# 0  2023-05-16 14:35:36  2023-05-16 14:37:16  a6b37a6b62   NaN
# 1  2023-05-16 14:34:03  2023-05-16 14:37:11  af85eeabbe   NaN
# 2  2023-05-16 14:31:14  2023-05-16 14:33:11  766275a4b0   NaN
# 3  2023-05-16 14:30:49  2023-05-16 14:32:48  913c34b0dc   NaN
# 4  2023-05-16 14:27:57  2023-05-16 14:30:33  e8a8a1b223   NaN

# %% [markdown]
# ### Lets remove some unnecesary columns that disturb us

# %%
# Drop the first column and last two columns
df = df.drop(df.columns[0], axis=1)  
df = df.iloc[:, :-4] 

df.head()
# Out:
#   ¿En qué rango de edad te encuentras?  \
# 0                   Entre 36 y 65 años
# 1                   Entre 36 y 65 años
# 2                   Entre 36 y 65 años
# 3                   Entre 36 y 65 años
# 4                   Entre 36 y 65 años
#
#    ¿Cuántas personas sois en vuestro hogar?  \
# 0                                       4.0
# 1                                       2.0
# 2                                       1.0
# 3                                       2.0
# 4                                       2.0
#
#   ¿En qué provincia vives? Vamos a conocernos un poco mejor 😄  \
# 0                                            Segovia
# 1                                             Madrid
# 2                                            Segovia
# 3                                             Madrid
# 4                                             Madrid
#
#   ¿De cuál de estos temas te interesaría saber más? ¿Cuánto duran tus duchas?  \
# 0                                    Ahorrar dinero      Entre 5 y 10 minutos
# 1                                      Ahorrar agua      Entre 5 y 10 minutos
# 2                              Ayudar al ecosistema      Entre 5 y 10 minutos
# 3                              Ayudar al ecosistema      Entre 5 y 10 minutos
# 4                              Ayudar al ecosistema         Más de 15 minutos
#
#   ¿Cuántas veces pones la lavadora a la semana?  \
# 0                             Entre 3 y 5 veces
# 1                              Menos de 3 veces
# 2                              Menos de 3 veces
# 3                             Entre 3 y 5 veces
# 4                             Entre 3 y 5 veces
#
#   ¿Cuántas veces pones el lavavajillas?  \
# 0                         Friego a mano
# 1                          1 vez al día
# 2                         Friego a mano
# 3               Entre 3 y 5 a la semana
# 4                         Friego a mano
#
#   ¿Sueles poner el modo *ECO *en tus electrodomésticos?  \
# 0                                            Siempre
# 1                                            A veces
# 2                                            Siempre
# 3                                            A veces
# 4                                            A veces
#
#   ¿Reciclas agua para usarlo en otras tareas?  \
# 0                 Buena idea! Voy a probarlo!
# 1                                          Si
# 2                                          No
# 3                                          No
# 4                 Buena idea! Voy a probarlo!
#
#   ¿*Reciclas *vidrio, cartón y plástico? ¿Cada cuánto consumes *carne*?  \
# 0                                Siempre                   1 vez al día
# 1                                Siempre              1 vez cada 3 días
# 2                                A veces              1 vez cada 3 días
# 3                                A veces                   1 vez al día
# 4                                A veces              1 vez cada 3 días
#
#   ¿Cuántos km haces a la semana en coche?  \
# 0                         Menos de 100 km
# 1                           Más de 200 km
# 2                         Menos de 100 km
# 3                            No uso coche
# 4                            No uso coche
#
#   ¿Cuánto gastas al mes en comida para gato/perro?  \
# 0                                 No tengo mascota
# 1                                 No tengo mascota
# 2                                 No tengo mascota
# 3                                 No tengo mascota
# 4                                    Menos de 50 €
#
#   ¿Cuántos metros cuadrados tiene tu jardín?  \
# 0                                          0
# 1                                          0
# 2                                          0
# 3                                        NaN
# 4                                          0
#
#   ¿Sabes cuánto dinero gastas en tu consumo de agua al mes?
# 0                                   Entre 10€ y 40 €
# 1                                      Menos de 10 €
# 2                                   Entre 10€ y 40 €
# 3                                   Entre 10€ y 40 €
# 4                                      Menos de 10 €

# %% [markdown]
# ## Feauture and Target Analysis
#
# The dataset contains a list of Spanish residents behaviour of their personal water consumption.
#
# It contains the following **features:**
#
# * Age
# * Nº residents
# * Province
# * Interests
# * Shower
# * Washing machine
# * Dishwasher
# * Eco Mode
# * Water recycling
# * General recycling
# * Meat Consumption
# * Pet
# * Garden area
# * Water estimation spent
#
# Since we are dealing with an unsupervised multi-class problem the expected **targets** may be as follows:
#
# * Expected groups:
#     * 0: Water Saver
#     * 1: Water Spender
#     * 2: Water unconscious

# %% [markdown]
# ### Rename columns

# %%
list = [ "Age",
 "Residents",
 "Province",
 "Interests",
 "Shower",
 "Wash-mach",
 "Dishwasher",
 "Eco-mode",
 "Water-recycling",
 "General-recycling",
 "Meat",
 "Gasoline",
 "Pet",
"Garden",
 "Estimation"]

for index,name in enumerate(list):
    df.rename(columns={df.columns[index]: name}, inplace=True)

df
# Out:
#                     Age  Residents  Province                  Interests  \
# 0    Entre 36 y 65 años        4.0   Segovia             Ahorrar dinero
# 1    Entre 36 y 65 años        2.0    Madrid               Ahorrar agua
# 2    Entre 36 y 65 años        1.0   Segovia       Ayudar al ecosistema
# 3    Entre 36 y 65 años        2.0    Madrid       Ayudar al ecosistema
# 4    Entre 36 y 65 años        2.0    Madrid       Ayudar al ecosistema
# ..                  ...        ...       ...                        ...
# 155  Entre 18 y 35 años        3.0    Madrid  Conocer mi huella hídrica
# 156  Entre 18 y 35 años        4.0    Madrid             Ahorrar dinero
# 157  Entre 36 y 65 años        5.0    Madrid             Ahorrar dinero
# 158                 NaN        NaN  A Coruña             Ahorrar dinero
# 159                 NaN        NaN  Albacete             Ahorrar dinero
#
#                     Shower          Wash-mach               Dishwasher  \
# 0     Entre 5 y 10 minutos  Entre 3 y 5 veces            Friego a mano
# 1     Entre 5 y 10 minutos   Menos de 3 veces             1 vez al día
# 2     Entre 5 y 10 minutos   Menos de 3 veces            Friego a mano
# 3     Entre 5 y 10 minutos  Entre 3 y 5 veces  Entre 3 y 5 a la semana
# 4        Más de 15 minutos  Entre 3 y 5 veces            Friego a mano
# ..                     ...                ...                      ...
# 155  Entre 11 y 15 minutos   Menos de 3 veces  Entre 3 y 5 a la semana
# 156   Entre 5 y 10 minutos  Entre 3 y 5 veces            Friego a mano
# 157  Entre 11 y 15 minutos  Entre 3 y 5 veces            Friego a mano
# 158   Entre 5 y 10 minutos   Menos de 3 veces             1 vez al día
# 159   Entre 5 y 10 minutos  Entre 3 y 5 veces            Friego a mano
#
#                           Eco-mode              Water-recycling  \
# 0                          Siempre  Buena idea! Voy a probarlo!
# 1                          A veces                           Si
# 2                          Siempre                           No
# 3                          A veces                           No
# 4                          A veces  Buena idea! Voy a probarlo!
# ..                             ...                          ...
# 155                        A veces  Buena idea! Voy a probarlo!
# 156                        A veces                           No
# 157                        A veces                           No
# 158                        A veces                           No
# 159  No sabía que existía ese modo                           No
#
#     General-recycling               Meat         Gasoline               Pet  \
# 0             Siempre       1 vez al día  Menos de 100 km  No tengo mascota
# 1             Siempre  1 vez cada 3 días    Más de 200 km  No tengo mascota
# 2             A veces  1 vez cada 3 días  Menos de 100 km  No tengo mascota
# 3             A veces       1 vez al día     No uso coche  No tengo mascota
# 4             A veces  1 vez cada 3 días     No uso coche     Menos de 50 €
# ..                ...                ...              ...               ...
# 155           A veces       1 vez al día    Más de 200 km  Entre 50 y 100 €
# 156           Siempre       1 vez al día    Más de 200 km  No tengo mascota
# 157           A veces  1 vez cada 3 días     No uso coche  No tengo mascota
# 158           Siempre  1 vez cada 3 días    Más de 200 km      Más de 100 €
# 159            Nunca!  1 vez a la semana     100 - 200 km  Entre 50 y 100 €
#
#     Garden        Estimation
# 0        0  Entre 10€ y 40 €
# 1        0     Menos de 10 €
# 2        0  Entre 10€ y 40 €
# 3      NaN  Entre 10€ y 40 €
# 4        0     Menos de 10 €
# ..     ...               ...
# 155      0  Entre 10€ y 40 €
# 156      0  Entre 10€ y 40 €
# 157      0       Más de 40 €
# 158    NaN               NaN
# 159    NaN               NaN
#
# [160 rows x 15 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 160 entries, 0 to 159
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Age                158 non-null    object
#  1   Residents          158 non-null    float64
#  2   Province           160 non-null    object
#  3   Interests          160 non-null    object
#  4   Shower             160 non-null    object
#  5   Wash-mach          160 non-null    object
#  6   Dishwasher         160 non-null    object
#  7   Eco-mode           160 non-null    object
#  8   Water-recycling    160 non-null    object
#  9   General-recycling  160 non-null    object
#  10  Meat               160 non-null    object
#  11  Gasoline           160 non-null    object
#  12  Pet                160 non-null    object
#  13  Garden             147 non-null    object
#  14  Estimation         158 non-null    object
# dtypes: float64(1), object(14)
# memory usage: 18.9+ KB

# %%
# Check for any NaN in df
df.isna().sum()
# Out:
# Age                   2
# Residents             2
# Province              0
# Interests             0
# Shower                0
# Wash-mach             0
# Dishwasher            0
# Eco-mode              0
# Water-recycling       0
# General-recycling     0
# Meat                  0
# Gasoline              0
# Pet                   0
# Garden               13
# Estimation            2
# dtype: int64
