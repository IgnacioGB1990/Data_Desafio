# %%
import pandas as pd

# %%
df = pd.read_csv('../data/full_stack_clean.csv')
df.head()
# Out:
#                   Age  Residents Province             Interests  \
# 0  Entre 36 y 65 años        4.0   Madrid  Ayudar al ecosistema
# 1  Entre 36 y 65 años        3.0  Segovia  Ayudar al ecosistema
# 2  Entre 36 y 65 años        2.0  Segovia        Ahorrar dinero
# 3  Entre 18 y 35 años        2.0  Segovia          Ahorrar agua
# 4  Entre 36 y 65 años        2.0   Madrid          Ahorrar agua
#
#                  Shower     WashingMachine               DishWasher  \
# 0  Entre 5 y 10 minutos  Entre 3 y 5 veces  Entre 3 y 5 a la semana
# 1    Menos de 5 minutos   Menos de 3 veces  Entre 3 y 5 a la semana
# 2    Menos de 5 minutos   Menos de 3 veces            Friego a mano
# 3  Entre 5 y 10 minutos   Menos de 3 veces            Friego a mano
# 4  Entre 5 y 10 minutos   Menos de 3 veces            Friego a mano
#
#                          EcoMode WaterRecycling GeneralRecycling  \
# 0                        A veces             No          Siempre
# 1                        Siempre             No          A veces
# 2  No sabía que existía ese modo             No          A veces
# 3                        Siempre             No          A veces
# 4                        A veces             Si          Siempre
#
#                 Meat         Gasoline               Pet  Garden  \
# 0       1 vez al día    Más de 200 km  No tengo mascota       0
# 1  1 vez cada 3 días  Menos de 100 km  No tengo mascota     300
# 2  1 vez a la semana     100 - 200 km  No tengo mascota       0
# 3       1 vez al día  Menos de 100 km  No tengo mascota       0
# 4  1 vez cada 3 días     No uso coche  No tengo mascota       2
#
#          Estimation
# 0          Ni idea!
# 1          Ni idea!
# 2          Ni idea!
# 3          Ni idea!
# 4  Entre 10€ y 40 €

# %%
# Definimos una función que calcule la huella hídrica total anual por cada respuesta de usuario:

def huella_hídrica_total_anual(row):

    quinto_elemento = row['Shower']
    sexto_elemento = row['WashingMachine']
    septimo_elemento = row['DishWasher']
    octavo_elemento = row['EcoMode']
    noveno_elemento = row['WaterRecycling']
    decimo_elemento = row['GeneralRecycling']
    undecimo_elemento = row['Meat']
    duodecimo_elemento = row['Gasoline']
    decimotercero_elemento = row['Pet']
    decimocuarto_elemento = row['Garden']


    if quinto_elemento == 'Menos de 5 minutos':
        huella_hidrica_ducha = 5 * (4 * 2.5 / 60) * 0.01 * 52 * 1000

    elif quinto_elemento == 'Entre 5 y 10 minutos':
        huella_hidrica_ducha = 5 * (7 * 2.5 / 60) * 0.01 * 52 * 1000

    elif quinto_elemento == 'Entre 11 y 15 minutos':
        huella_hidrica_ducha = 5 * (12 * 2.5 / 60) * 0.01 * 52 * 1000

    elif quinto_elemento == 'Más de 15 minutos':
        huella_hidrica_ducha = 5 * (20 * 2.5 / 60) * 0.01 * 52 * 1000


    if sexto_elemento == 'Menos de 3 veces':
        huella_hidrica_lavadora = 1 * 15 * 0.01 * 52 * 1000
        
    elif sexto_elemento == 'Entre 3 y 5 veces':
        huella_hidrica_lavadora = 4 * 15 * 0.01 * 52 * 1000

    elif sexto_elemento == 'Más de 5':
        huella_hidrica_lavadora = 6 * 15 * 0.01 * 52 * 1000


    if septimo_elemento == '1 vez al día':
        huella_hidrica_lavar_platos = 1 * 6.5 * 0.01 * 52 * 1000

    elif septimo_elemento == 'Entre 3 y 5 a la semana':
        huella_hidrica_lavar_platos = 5 * 6.5 * 0.01 * 52 * 1000

    elif septimo_elemento == 'Friego a mano':
        huella_hidrica_lavar_platos = 10 * 27 * 0.01 * 52 * 1000


    if octavo_elemento == 'Siempre':
        huella_hidrica_para_modo_eco = - ((7800 + 23659.3) * 36) / 100

    elif octavo_elemento == 'A veces':
        huella_hidrica_para_modo_eco = - ((7800 + 23659.3) * 18) / 100

    elif octavo_elemento == 'No sabía que existía ese modo':
        huella_hidrica_para_modo_eco = 0


    if noveno_elemento == 'Si':
        huella_hidrica_ahorro_agua = - 730

    elif noveno_elemento == 'No':
        huella_hidrica_ahorro_agua = 0

    elif noveno_elemento == 'Buena idea! Voy a probarlo!':
        huella_hidrica_ahorro_agua = 0


    if decimo_elemento == 'A veces':
        huella_hidrica_reciclaje = - 730

    elif decimo_elemento == 'Siempre':
        huella_hidrica_reciclaje = - 1460

    elif decimo_elemento == 'Nunca!':
        huella_hidrica_reciclaje = 0


    if undecimo_elemento == '1 vez al día':
        huella_hidrica_carne = 768 * 0.01 * 1000 * 365

    elif undecimo_elemento == '1 vez cada 3 días':
        huella_hidrica_carne = 596 * 0.01 * 1000 * 365

    elif undecimo_elemento == '1 vez a la semana':
        huella_hidrica_carne = 563 * 0.01 * 1000 * 365

    elif undecimo_elemento == 'Nunca!':
        huella_hidrica_carne = 406 * 0.01 * 1000 * 365


    if duodecimo_elemento == 'Menos de 100 km':
        huella_hidrica_gasolina = (6 * 52) * 97

    elif duodecimo_elemento == '100 - 200 km':
        huella_hidrica_gasolina = (15 * 52) * 97

    elif duodecimo_elemento == 'Más de 200 km':
        huella_hidrica_gasolina = (25 * 52) * 97

    elif duodecimo_elemento == 'No uso coche':
        huella_hidrica_gasolina = 0


    if decimotercero_elemento == 'No tengo mascota':
        huella_hidrica_mascota = 358.75 * 1000

    elif decimotercero_elemento == 'Menos de 50 €':
        huella_hidrica_mascota = 40 * 358750 / 75

    elif decimotercero_elemento == 'Entre 50 y 100 €':
        huella_hidrica_mascota = 75 * 358750 / 75

    elif decimotercero_elemento == 'Más de 100 €':
        huella_hidrica_mascota = 120 * 358750 / 75


    if decimocuarto_elemento != 0:
        huella_hidrica_jardin = 6 * decimocuarto_elemento
    else:
        huella_hidrica_jardin = 0

    huella_hidrica_total_anual  = huella_hidrica_ducha + huella_hidrica_lavadora + huella_hidrica_lavar_platos + huella_hidrica_para_modo_eco + huella_hidrica_ahorro_agua + huella_hidrica_reciclaje + huella_hidrica_carne + huella_hidrica_gasolina + huella_hidrica_mascota + huella_hidrica_jardin

    return huella_hidrica_total_anual

# Definimos una función que calcule la huella hídrica total diaria por cada respuesta de usuario:

def huella_hídrica_total_diaria(huella_hidrica_total_anual):

    huella_hidrica_total_diaria = huella_hidrica_total_anual / 365

    return huella_hidrica_total_diaria

# %%
Huella_Hídrica_Anual = df.apply(huella_hídrica_total_anual, axis=1)

df['AnnualWaterFootprint'] = Huella_Hídrica_Anual

# %%
df['DiaryWaterFootprint'] = df['AnnualWaterFootprint'].apply(huella_hídrica_total_diaria)

# %%
df.head()
# Out:
#                   Age  Residents Province             Interests  \
# 0  Entre 36 y 65 años        4.0   Madrid  Ayudar al ecosistema
# 1  Entre 36 y 65 años        3.0  Segovia  Ayudar al ecosistema
# 2  Entre 36 y 65 años        2.0  Segovia        Ahorrar dinero
# 3  Entre 18 y 35 años        2.0  Segovia          Ahorrar agua
# 4  Entre 36 y 65 años        2.0   Madrid          Ahorrar agua
#
#                  Shower     WashingMachine               DishWasher  \
# 0  Entre 5 y 10 minutos  Entre 3 y 5 veces  Entre 3 y 5 a la semana
# 1    Menos de 5 minutos   Menos de 3 veces  Entre 3 y 5 a la semana
# 2    Menos de 5 minutos   Menos de 3 veces            Friego a mano
# 3  Entre 5 y 10 minutos   Menos de 3 veces            Friego a mano
# 4  Entre 5 y 10 minutos   Menos de 3 veces            Friego a mano
#
#                          EcoMode WaterRecycling GeneralRecycling  \
# 0                        A veces             No          Siempre
# 1                        Siempre             No          A veces
# 2  No sabía que existía ese modo             No          A veces
# 3                        Siempre             No          A veces
# 4                        A veces             Si          Siempre
#
#                 Meat         Gasoline               Pet  Garden  \
# 0       1 vez al día    Más de 200 km  No tengo mascota       0
# 1  1 vez cada 3 días  Menos de 100 km  No tengo mascota     300
# 2  1 vez a la semana     100 - 200 km  No tengo mascota       0
# 3       1 vez al día  Menos de 100 km  No tengo mascota       0
# 4  1 vez cada 3 días     No uso coche  No tengo mascota       2
#
#          Estimation  AnnualWaterFootprint  DiaryWaterFootprint
# 0          Ni idea!          3.329786e+06          9122.700437
# 1          Ni idea!          2.579292e+06          7066.553384
# 2          Ni idea!          2.637263e+06          7225.378995
# 3          Ni idea!          3.329117e+06          9120.868453
# 4  Entre 10€ y 40 €          2.675268e+06          7329.500437

# %%
# El m3 (1000L) de agua en España esta a 1.91€.

def costo_anual(huella_anual):
    costo_anual_agua = huella_anual * 1.91
    return costo_anual_agua

df['AnnualCost'] = df['AnnualWaterFootprint'].apply(costo_anual)

# %%
df['DiaryCost'] = df['AnnualCost'].apply(huella_hídrica_total_diaria)

# %%
df.head()
# Out:
#                   Age  Residents Province             Interests  \
# 0  Entre 36 y 65 años        4.0   Madrid  Ayudar al ecosistema
# 1  Entre 36 y 65 años        3.0  Segovia  Ayudar al ecosistema
# 2  Entre 36 y 65 años        2.0  Segovia        Ahorrar dinero
# 3  Entre 18 y 35 años        2.0  Segovia          Ahorrar agua
# 4  Entre 36 y 65 años        2.0   Madrid          Ahorrar agua
#
#                  Shower     WashingMachine               DishWasher  \
# 0  Entre 5 y 10 minutos  Entre 3 y 5 veces  Entre 3 y 5 a la semana
# 1    Menos de 5 minutos   Menos de 3 veces  Entre 3 y 5 a la semana
# 2    Menos de 5 minutos   Menos de 3 veces            Friego a mano
# 3  Entre 5 y 10 minutos   Menos de 3 veces            Friego a mano
# 4  Entre 5 y 10 minutos   Menos de 3 veces            Friego a mano
#
#                          EcoMode WaterRecycling GeneralRecycling  \
# 0                        A veces             No          Siempre
# 1                        Siempre             No          A veces
# 2  No sabía que existía ese modo             No          A veces
# 3                        Siempre             No          A veces
# 4                        A veces             Si          Siempre
#
#                 Meat         Gasoline               Pet  Garden  \
# 0       1 vez al día    Más de 200 km  No tengo mascota       0
# 1  1 vez cada 3 días  Menos de 100 km  No tengo mascota     300
# 2  1 vez a la semana     100 - 200 km  No tengo mascota       0
# 3       1 vez al día  Menos de 100 km  No tengo mascota       0
# 4  1 vez cada 3 días     No uso coche  No tengo mascota       2
#
#          Estimation  AnnualWaterFootprint  DiaryWaterFootprint    AnnualCost  \
# 0          Ni idea!          3.329786e+06          9122.700437  6.359891e+06
# 1          Ni idea!          2.579292e+06          7066.553384  4.926448e+06
# 2          Ni idea!          2.637263e+06          7225.378995  5.037173e+06
# 3          Ni idea!          3.329117e+06          9120.868453  6.358613e+06
# 4  Entre 10€ y 40 €          2.675268e+06          7329.500437  5.109761e+06
#
#       DiaryCost
# 0  17424.357834
# 1  13497.116964
# 2  13800.473881
# 3  17420.858745
# 4  13999.345834

# %%
def huella_hídrica_total_anual2(row):

    quinto_elemento = row['Shower']
    sexto_elemento = row['WashingMachine']
    septimo_elemento = row['DishWasher']
    octavo_elemento = row['EcoMode']

    if quinto_elemento == 'Menos de 5 minutos':
        huella_hidrica_ducha = 5 * (4 * 2.5 / 60) * 0.01 * 52 * 1000

    elif quinto_elemento == 'Entre 5 y 10 minutos':
        huella_hidrica_ducha = 5 * (7 * 2.5 / 60) * 0.01 * 52 * 1000

    elif quinto_elemento == 'Entre 11 y 15 minutos':
        huella_hidrica_ducha = 5 * (12 * 2.5 / 60) * 0.01 * 52 * 1000

    elif quinto_elemento == 'Más de 15 minutos':
        huella_hidrica_ducha = 5 * (20 * 2.5 / 60) * 0.01 * 52 * 1000


    if sexto_elemento == 'Menos de 3 veces':
        huella_hidrica_lavadora = 1 * 15 * 0.01 * 52 * 1000
        
    elif sexto_elemento == 'Entre 3 y 5 veces':
        huella_hidrica_lavadora = 4 * 15 * 0.01 * 52 * 1000

    elif sexto_elemento == 'Más de 5':
        huella_hidrica_lavadora = 6 * 15 * 0.01 * 52 * 1000


    if septimo_elemento == '1 vez al día':
        huella_hidrica_lavar_platos = 1 * 6.5 * 0.01 * 52 * 1000

    elif septimo_elemento == 'Entre 3 y 5 a la semana':
        huella_hidrica_lavar_platos = 5 * 6.5 * 0.01 * 52 * 1000

    elif septimo_elemento == 'Friego a mano':
        huella_hidrica_lavar_platos = 10 * 27 * 0.01 * 52 * 1000


    if octavo_elemento == 'Siempre':
        huella_hidrica_para_modo_eco = - ((7800 + 23659.3) * 36) / 100

    elif octavo_elemento == 'A veces':
        huella_hidrica_para_modo_eco = - ((7800 + 23659.3) * 18) / 100

    elif octavo_elemento == 'No sabía que existía ese modo':
        huella_hidrica_para_modo_eco = 0

    huella_hidrica_total_anual2 = huella_hidrica_ducha + huella_hidrica_lavadora + huella_hidrica_lavar_platos + huella_hidrica_para_modo_eco

    return huella_hidrica_total_anual2

# %%
Huella_Hídrica_Anual_Directa = df.apply(huella_hídrica_total_anual2, axis=1)

df['AnnualDirectWaterFootprint'] = Huella_Hídrica_Anual_Directa

# %%
df['DiaryDirectWaterFootprint'] = df['AnnualDirectWaterFootprint'].apply(huella_hídrica_total_diaria)

# %%
df['DirectAnnualCost'] = df['AnnualDirectWaterFootprint'].apply(costo_anual)

# %%
df['DirectDiaryCost'] = df['DirectAnnualCost'].apply(huella_hídrica_total_diaria)

# %%
df.head()
# Out:
#                   Age  Residents Province             Interests  \
# 0  Entre 36 y 65 años        4.0   Madrid  Ayudar al ecosistema
# 1  Entre 36 y 65 años        3.0  Segovia  Ayudar al ecosistema
# 2  Entre 36 y 65 años        2.0  Segovia        Ahorrar dinero
# 3  Entre 18 y 35 años        2.0  Segovia          Ahorrar agua
# 4  Entre 36 y 65 años        2.0   Madrid          Ahorrar agua
#
#                  Shower     WashingMachine               DishWasher  \
# 0  Entre 5 y 10 minutos  Entre 3 y 5 veces  Entre 3 y 5 a la semana
# 1    Menos de 5 minutos   Menos de 3 veces  Entre 3 y 5 a la semana
# 2    Menos de 5 minutos   Menos de 3 veces            Friego a mano
# 3  Entre 5 y 10 minutos   Menos de 3 veces            Friego a mano
# 4  Entre 5 y 10 minutos   Menos de 3 veces            Friego a mano
#
#                          EcoMode WaterRecycling GeneralRecycling  ... Garden  \
# 0                        A veces             No          Siempre  ...      0
# 1                        Siempre             No          A veces  ...    300
# 2  No sabía que existía ese modo             No          A veces  ...      0
# 3                        Siempre             No          A veces  ...      0
# 4                        A veces             Si          Siempre  ...      2
#
#          Estimation AnnualWaterFootprint  DiaryWaterFootprint    AnnualCost  \
# 0          Ni idea!         3.329786e+06          9122.700437  6.359891e+06
# 1          Ni idea!         2.579292e+06          7066.553384  4.926448e+06
# 2          Ni idea!         2.637263e+06          7225.378995  5.037173e+06
# 3          Ni idea!         3.329117e+06          9120.868453  6.358613e+06
# 4  Entre 10€ y 40 €         2.675268e+06          7329.500437  5.109761e+06
#
#       DiaryCost  AnnualDirectWaterFootprint  DiaryDirectWaterFootprint  \
# 0  17424.357834                43195.659333                 118.344272
# 1  13497.116964                13807.985333                  37.830097
# 2  13800.473881               148633.333333                 407.214612
# 3  17420.858745               137632.985333                 377.076672
# 4  13999.345834               143295.659333                 392.590847
#
#    DirectAnnualCost  DirectDiaryCost
# 0      82503.709327       226.037560
# 1      26373.251987        72.255485
# 2     283889.666667       777.779909
# 3     262879.001987       720.216444
# 4     273694.709327       749.848519
#
# [5 rows x 23 columns]

# %%
def formateo(num):
    formatear = "{:.0f}".format(num)
    return formatear

df['AnnualWaterFootprint'] = df['AnnualWaterFootprint'].apply(formateo)

# %%
df['AnnualCost'] = df['AnnualCost'].apply(formateo)

# %%
df.head()
# Out:
#                   Age  Residents Province             Interests  \
# 0  Entre 36 y 65 años        4.0   Madrid  Ayudar al ecosistema
# 1  Entre 36 y 65 años        3.0  Segovia  Ayudar al ecosistema
# 2  Entre 36 y 65 años        2.0  Segovia        Ahorrar dinero
# 3  Entre 18 y 35 años        2.0  Segovia          Ahorrar agua
# 4  Entre 36 y 65 años        2.0   Madrid          Ahorrar agua
#
#                  Shower     WashingMachine               DishWasher  \
# 0  Entre 5 y 10 minutos  Entre 3 y 5 veces  Entre 3 y 5 a la semana
# 1    Menos de 5 minutos   Menos de 3 veces  Entre 3 y 5 a la semana
# 2    Menos de 5 minutos   Menos de 3 veces            Friego a mano
# 3  Entre 5 y 10 minutos   Menos de 3 veces            Friego a mano
# 4  Entre 5 y 10 minutos   Menos de 3 veces            Friego a mano
#
#                          EcoMode WaterRecycling GeneralRecycling  ... Garden  \
# 0                        A veces             No          Siempre  ...      0
# 1                        Siempre             No          A veces  ...    300
# 2  No sabía que existía ese modo             No          A veces  ...      0
# 3                        Siempre             No          A veces  ...      0
# 4                        A veces             Si          Siempre  ...      2
#
#          Estimation AnnualWaterFootprint  DiaryWaterFootprint AnnualCost  \
# 0          Ni idea!              3329786          9122.700437    6359891
# 1          Ni idea!              2579292          7066.553384    4926448
# 2          Ni idea!              2637263          7225.378995    5037173
# 3          Ni idea!              3329117          9120.868453    6358613
# 4  Entre 10€ y 40 €              2675268          7329.500437    5109761
#
#       DiaryCost  AnnualDirectWaterFootprint DiaryDirectWaterFootprint  \
# 0  17424.357834                43195.659333                118.344272
# 1  13497.116964                13807.985333                 37.830097
# 2  13800.473881               148633.333333                407.214612
# 3  17420.858745               137632.985333                377.076672
# 4  13999.345834               143295.659333                392.590847
#
#    DirectAnnualCost  DirectDiaryCost
# 0      82503.709327       226.037560
# 1      26373.251987        72.255485
# 2     283889.666667       777.779909
# 3     262879.001987       720.216444
# 4     273694.709327       749.848519
#
# [5 rows x 23 columns]

# %%
df['DiaryWaterFootprint'] = df['DiaryWaterFootprint'].apply(lambda x : round(x, 2))
df['DiaryCost'] = df['DiaryCost'].apply(lambda x : round(x, 2))
df['AnnualDirectWaterFootprint'] = df['AnnualDirectWaterFootprint'].apply(lambda x : round(x, 2))
df['DiaryDirectWaterFootprint'] = df['DiaryDirectWaterFootprint'].apply(lambda x : round(x, 2))
df['DirectAnnualCost'] = df['DirectAnnualCost'].apply(lambda x : round(x, 2))
df['DirectDiaryCost'] = df['DirectDiaryCost'].apply(lambda x : round(x, 2))

# %%
df
# Out:
#                      Age  Residents Province                  Interests  \
# 0     Entre 36 y 65 años        4.0   Madrid       Ayudar al ecosistema
# 1     Entre 36 y 65 años        3.0  Segovia       Ayudar al ecosistema
# 2     Entre 36 y 65 años        2.0  Segovia             Ahorrar dinero
# 3     Entre 18 y 35 años        2.0  Segovia               Ahorrar agua
# 4     Entre 36 y 65 años        2.0   Madrid               Ahorrar agua
# ...                  ...        ...      ...                        ...
# 1173  Entre 36 y 65 años        4.0   Madrid               Ahorrar agua
# 1174  Entre 36 y 65 años        5.0   Madrid             Ahorrar dinero
# 1175  Entre 18 y 35 años        3.0   Madrid  Conocer mi huella hídrica
# 1176  Entre 18 y 35 años        4.0   Madrid             Ahorrar dinero
# 1177  Entre 36 y 65 años        5.0   Madrid             Ahorrar dinero
#
#                      Shower     WashingMachine               DishWasher  \
# 0      Entre 5 y 10 minutos  Entre 3 y 5 veces  Entre 3 y 5 a la semana
# 1        Menos de 5 minutos   Menos de 3 veces  Entre 3 y 5 a la semana
# 2        Menos de 5 minutos   Menos de 3 veces            Friego a mano
# 3      Entre 5 y 10 minutos   Menos de 3 veces            Friego a mano
# 4      Entre 5 y 10 minutos   Menos de 3 veces            Friego a mano
# ...                     ...                ...                      ...
# 1173   Entre 5 y 10 minutos  Entre 3 y 5 veces  Entre 3 y 5 a la semana
# 1174     Menos de 5 minutos           Más de 5  Entre 3 y 5 a la semana
# 1175  Entre 11 y 15 minutos   Menos de 3 veces  Entre 3 y 5 a la semana
# 1176   Entre 5 y 10 minutos  Entre 3 y 5 veces            Friego a mano
# 1177  Entre 11 y 15 minutos  Entre 3 y 5 veces            Friego a mano
#
#                             EcoMode               WaterRecycling  \
# 0                           A veces                           No
# 1                           Siempre                           No
# 2     No sabía que existía ese modo                           No
# 3                           Siempre                           No
# 4                           A veces                           Si
# ...                             ...                          ...
# 1173                        A veces                           No
# 1174  No sabía que existía ese modo                           No
# 1175                        A veces  Buena idea! Voy a probarlo!
# 1176                        A veces                           No
# 1177                        A veces                           No
#
#      GeneralRecycling  ... Garden        Estimation AnnualWaterFootprint  \
# 0             Siempre  ...      0          Ni idea!              3329786
# 1             A veces  ...    300          Ni idea!              2579292
# 2             A veces  ...      0          Ni idea!              2637263
# 3             A veces  ...      0          Ni idea!              3329117
# 4             Siempre  ...      2  Entre 10€ y 40 €              2675268
# ...               ...  ...    ...               ...                  ...
# 1173          Siempre  ...      0          Ni idea!              3233950
# 1174           Nunca!  ...      0  Entre 10€ y 40 €              2553493
# 1175          A veces  ...      0  Entre 10€ y 40 €              3307657
# 1176          Siempre  ...      0  Entre 10€ y 40 €              3453286
# 1177          A veces  ...      0       Más de 40 €              2700657
#
#       DiaryWaterFootprint AnnualCost DiaryCost  AnnualDirectWaterFootprint  \
# 0                 9122.70    6359891  17424.36                    43195.66
# 1                 7066.55    4926448  13497.12                    13807.99
# 2                 7225.38    5037173  13800.47                   148633.33
# 3                 9120.87    6358613  17420.86                   137632.99
# 4                 7329.50    5109761  13999.35                   143295.66
# ...                   ...        ...       ...                         ...
# 1173              8860.14    6176844  16922.86                    43195.66
# 1174              6995.87    4877172  13362.12                    64133.33
# 1175              9062.07    6317625  17308.56                    20337.33
# 1176              9461.06    6595776  18070.62                   166695.66
# 1177              7399.06    5158255  14132.21                   167237.33
#
#      DiaryDirectWaterFootprint  DirectAnnualCost  DirectDiaryCost
# 0                       118.34          82503.71           226.04
# 1                        37.83          26373.25            72.26
# 2                       407.21         283889.67           777.78
# 3                       377.08         262879.00           720.22
# 4                       392.59         273694.71           749.85
# ...                        ...               ...              ...
# 1173                    118.34          82503.71           226.04
# 1174                    175.71         122494.67           335.60
# 1175                     55.72          38844.29           106.42
# 1176                    456.70         318388.71           872.30
# 1177                    458.18         319423.29           875.13
#
# [1178 rows x 23 columns]

# %%
df['Residents'] = df['Residents'].astype(int)

# %%
df
# Out:
#                      Age  Residents Province                  Interests  \
# 0     Entre 36 y 65 años          4   Madrid       Ayudar al ecosistema
# 1     Entre 36 y 65 años          3  Segovia       Ayudar al ecosistema
# 2     Entre 36 y 65 años          2  Segovia             Ahorrar dinero
# 3     Entre 18 y 35 años          2  Segovia               Ahorrar agua
# 4     Entre 36 y 65 años          2   Madrid               Ahorrar agua
# ...                  ...        ...      ...                        ...
# 1173  Entre 36 y 65 años          4   Madrid               Ahorrar agua
# 1174  Entre 36 y 65 años          5   Madrid             Ahorrar dinero
# 1175  Entre 18 y 35 años          3   Madrid  Conocer mi huella hídrica
# 1176  Entre 18 y 35 años          4   Madrid             Ahorrar dinero
# 1177  Entre 36 y 65 años          5   Madrid             Ahorrar dinero
#
#                      Shower     WashingMachine               DishWasher  \
# 0      Entre 5 y 10 minutos  Entre 3 y 5 veces  Entre 3 y 5 a la semana
# 1        Menos de 5 minutos   Menos de 3 veces  Entre 3 y 5 a la semana
# 2        Menos de 5 minutos   Menos de 3 veces            Friego a mano
# 3      Entre 5 y 10 minutos   Menos de 3 veces            Friego a mano
# 4      Entre 5 y 10 minutos   Menos de 3 veces            Friego a mano
# ...                     ...                ...                      ...
# 1173   Entre 5 y 10 minutos  Entre 3 y 5 veces  Entre 3 y 5 a la semana
# 1174     Menos de 5 minutos           Más de 5  Entre 3 y 5 a la semana
# 1175  Entre 11 y 15 minutos   Menos de 3 veces  Entre 3 y 5 a la semana
# 1176   Entre 5 y 10 minutos  Entre 3 y 5 veces            Friego a mano
# 1177  Entre 11 y 15 minutos  Entre 3 y 5 veces            Friego a mano
#
#                             EcoMode               WaterRecycling  \
# 0                           A veces                           No
# 1                           Siempre                           No
# 2     No sabía que existía ese modo                           No
# 3                           Siempre                           No
# 4                           A veces                           Si
# ...                             ...                          ...
# 1173                        A veces                           No
# 1174  No sabía que existía ese modo                           No
# 1175                        A veces  Buena idea! Voy a probarlo!
# 1176                        A veces                           No
# 1177                        A veces                           No
#
#      GeneralRecycling  ... Garden        Estimation AnnualWaterFootprint  \
# 0             Siempre  ...      0          Ni idea!              3329786
# 1             A veces  ...    300          Ni idea!              2579292
# 2             A veces  ...      0          Ni idea!              2637263
# 3             A veces  ...      0          Ni idea!              3329117
# 4             Siempre  ...      2  Entre 10€ y 40 €              2675268
# ...               ...  ...    ...               ...                  ...
# 1173          Siempre  ...      0          Ni idea!              3233950
# 1174           Nunca!  ...      0  Entre 10€ y 40 €              2553493
# 1175          A veces  ...      0  Entre 10€ y 40 €              3307657
# 1176          Siempre  ...      0  Entre 10€ y 40 €              3453286
# 1177          A veces  ...      0       Más de 40 €              2700657
#
#       DiaryWaterFootprint AnnualCost DiaryCost  AnnualDirectWaterFootprint  \
# 0                 9122.70    6359891  17424.36                    43195.66
# 1                 7066.55    4926448  13497.12                    13807.99
# 2                 7225.38    5037173  13800.47                   148633.33
# 3                 9120.87    6358613  17420.86                   137632.99
# 4                 7329.50    5109761  13999.35                   143295.66
# ...                   ...        ...       ...                         ...
# 1173              8860.14    6176844  16922.86                    43195.66
# 1174              6995.87    4877172  13362.12                    64133.33
# 1175              9062.07    6317625  17308.56                    20337.33
# 1176              9461.06    6595776  18070.62                   166695.66
# 1177              7399.06    5158255  14132.21                   167237.33
#
#      DiaryDirectWaterFootprint  DirectAnnualCost  DirectDiaryCost
# 0                       118.34          82503.71           226.04
# 1                        37.83          26373.25            72.26
# 2                       407.21         283889.67           777.78
# 3                       377.08         262879.00           720.22
# 4                       392.59         273694.71           749.85
# ...                        ...               ...              ...
# 1173                    118.34          82503.71           226.04
# 1174                    175.71         122494.67           335.60
# 1175                     55.72          38844.29           106.42
# 1176                    456.70         318388.71           872.30
# 1177                    458.18         319423.29           875.13
#
# [1178 rows x 23 columns]

# %%
dataset = '../data/Clean_dataset_final.xlsx'
#df.to_excel(dataset, index=False)
